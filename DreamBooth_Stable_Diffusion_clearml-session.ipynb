# %% [markdown]
# # Dreambooth Stable Diffusion

# %% [markdown]
# source: https://github.com/ShivamShrirao/diffusers/tree/main/examples/dreambooth

# %% [markdown]
# In your local environment start a Juypeter Lab server by calling
# note: change the project name to yours

# %%
clearml-session --project "ClearML Tutorial" --queue "<=48GB" --docker nvidia/cuda:11.6.0-cudnn8-runtime-ubuntu20.04 --vscode-server false --jupyter-lab true

# %%
#@markdown Check type of GPU and VRAM available.
# !nvidia-smi --query-gpu=name,memory.total,memory.free --format=csv,noheader
# Out:
# NVIDIA A40-48C, 49152 MiB, 45174 MiB

# %% [markdown]
# ## Install Requirements

# %%
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/examples/dreambooth/train_dreambooth.py
# !wget -q https://github.com/ShivamShrirao/diffusers/raw/main/scripts/convert_diffusers_to_original_stable_diffusion.py
# !pip install -qq git+https://github.com/ShivamShrirao/diffusers
# !pip install -q -U --pre triton
# !pip install -q accelerate transformers ftfy bitsandbytes==0.35.0 natsort safetensors torchvision
# !pip install -q xformers==0.0.17.dev447
# !pip install -q matplotlib
# Out:
# WARNING: You are using pip version 20.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/.clearml/venvs-builds/3.8/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/.clearml/venvs-builds/3.8/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/.clearml/venvs-builds/3.8/bin/python -m pip install --upgrade pip' command.
# WARNING: You are using pip version 20.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the '/root/.clearml/venvs-builds/3.8/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# A workaround to fix a bug from int8 inference (bitsandbytes)

# %%
# !ls /usr/local/cuda/lib64/libcudart.so*
# Out:
# /usr/local/cuda/lib64/libcudart.so.11.0
# /usr/local/cuda/lib64/libcudart.so.11.6.55

# %% [markdown]
# If you do not see libcudart.so, run the cells below

# %%
# !cp /usr/local/cuda/lib64/libcudart.so.11.0 /usr/local/cuda/lib64/libcudart.so

# %%
# !ls /usr/local/cuda/lib64/libcudart.so*
# you should see libcudart.so
# Out:
# /usr/local/cuda/lib64/libcudart.so
# /usr/local/cuda/lib64/libcudart.so.11.0
# /usr/local/cuda/lib64/libcudart.so.11.6.55

# %% [markdown]
# ## Upload your images for training

# %%
#@title Login to HuggingFace 🤗 (It also works if you skip it)

#@markdown You need to accept the model license before downloading or using the Stable Diffusion weights. Please, visit the [model card](https://huggingface.co/runwayml/stable-diffusion-v1-5), read the license and tick the checkbox if you agree. You have to be a registered user in 🤗 Hugging Face Hub, and you'll also need to use an access token for the code to work.
# https://huggingface.co/settings/tokens
# !mkdir -p ~/.huggingface
HUGGINGFACE_TOKEN = "" #@param {type:"string"}
# !echo -n "{HUGGINGFACE_TOKEN}" > ~/.huggingface/token

# %% [markdown]
# Create a folder and put about 5-10 images (of the same object/person) for the training there.
# Also, specify the folder name in the cell below.

# %%
#@markdown Enter the directory name of your input images (to train the model).
INPUT_IMAGES_DIR = "bear" #@param {type:"string"}

#@markdown Object name used in the prompt, e.g., "a photo of [object_name] person".
OBJECT_NAME = "bfn"

#@markdown Name/Path of the initial model.
MODEL_NAME = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}

#@markdown Enter the directory name to save model at.

OUTPUT_DIR = "stable_diffusion_weights/" + OBJECT_NAME #@param {type:"string"}
OUTPUT_DIR = "content/" + OUTPUT_DIR


import os
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"[*] Weights will be saved at {OUTPUT_DIR}")
# Out:
# [*] Weights will be saved at content/stable_diffusion_weights/bfn

# %% [markdown]
# ## Specify the prompts for training

# %%
# You can also add multiple concepts here. Try tweaking `--max_train_steps` accordingly.

concepts_list = [
#    {
#        "instance_prompt":      "photo of zwx dog",
#        "class_prompt":         "photo of a dog",
#        "instance_data_dir":    "./content/data/zwx",
#       "class_data_dir":       "./content/data/dog"
#    },
     {
         "instance_prompt":      f"photo of {OBJECT_NAME} bear",
         "class_prompt":         "photo of a bear",
         "instance_data_dir":    f"content/data/{OBJECT_NAME}",
         "class_data_dir":       "content/data/bear"
     }
]

# `class_data_dir` contains regularization images
import json
import os
for c in concepts_list:
    print(c["instance_data_dir"])
    os.makedirs(c["instance_data_dir"], exist_ok=True)

with open("concepts_list.json", "w") as f:
    json.dump(concepts_list, f, indent=4)
# Out:
# content/data/bfn

# %% [markdown]
# Move your input images to the instance_data_dir folder

# %%
#@markdown Make sure you already put your images in the input image folder you chose
import os

import shutil

for c in concepts_list:
    print(f"Uploading instance images for `{c['instance_prompt']}`")

    #filenames = [os.path.join("pikachu", f) for f in os.listdir("pikachu") if f[-3:] == "jpg"]

    for filename in os.listdir(INPUT_IMAGES_DIR):
        print(filename)
        filename_full = os.path.join(INPUT_IMAGES_DIR, filename)
        dst_path = os.path.join(c['instance_data_dir'], filename)
        shutil.copy(filename_full, dst_path)
# Out:
# Uploading instance images for `photo of bfn bear`
# bear4.jpg
# bear10.jpg
# bear9.jpg
# bear6.jpg
# bear11.jpg
# bear3.jpg
# bear1.jpg
# bear2.jpg
# bear7.jpg
# bear8.jpg
# bear5.jpg

# %% [markdown]
# ## Start Training

# %% [markdown]
# Use the table below to choose the best flags based on your memory and speed requirements. Tested on Tesla T4 GPU.
#
#
# | `fp16` | `train_batch_size` | `gradient_accumulation_steps` | `gradient_checkpointing` | `use_8bit_adam` | GB VRAM usage | Speed (it/s) |
# | ---- | ------------------ | ----------------------------- | ----------------------- | --------------- | ---------- | ------------ |
# | fp16 | 1                  | 1                             | TRUE                    | TRUE            | 9.92       | 0.93         |
# | no   | 1                  | 1                             | TRUE                    | TRUE            | 10.08      | 0.42         |
# | fp16 | 2                  | 1                             | TRUE                    | TRUE            | 10.4       | 0.66         |
# | fp16 | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 1.14         |
# | no   | 1                  | 1                             | FALSE                   | TRUE            | 11.17      | 0.49         |
# | fp16 | 1                  | 2                             | TRUE                    | TRUE            | 11.56      | 1            |
# | fp16 | 2                  | 1                             | FALSE                   | TRUE            | 13.67      | 0.82         |
# | fp16 | 1                  | 2                             | FALSE                   | TRUE            | 13.7       | 0.83          |
# | fp16 | 1                  | 1                             | TRUE                    | FALSE           | 15.79      | 0.77         |

# %% [markdown]
# Add `--gradient_checkpointing` flag for around 9.92 GB VRAM usage.
#
# remove `--use_8bit_adam` flag for full precision. Requires 15.79 GB with `--gradient_checkpointing` else 17.8 GB.
#
# remove `--train_text_encoder` flag to reduce memory usage further, degrades output quality.

# %% [markdown]
# If you get CUDA out of memory problem, shutdown the kernel, wait for a while, restart the kernel, and run the code from the beginning (except the package installation parts). Do not forget to remove "content" folder before you rerun the code.

# %%
# !accelerate launch train_dreambooth.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --pretrained_vae_name_or_path="stabilityai/sd-vae-ft-mse" \
  --output_dir=$OUTPUT_DIR \
  --revision="fp16" \
  --with_prior_preservation --prior_loss_weight=1.0 \
  --seed=1337 \
  --use_8bit_adam \
  --resolution=512 \
  --train_batch_size=1 \
  --train_text_encoder \
  --mixed_precision="fp16" \
  --gradient_accumulation_steps=1 \
  --learning_rate=1e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --num_class_images=50 \
  --sample_batch_size=4 \
  --max_train_steps=800 \
  --save_interval=10000 \
  --save_sample_prompt="photo of bfn bear" \
  --concepts_list="concepts_list.json"

# Reduce the `--save_interval` to lower than `--max_train_steps` to save weights from intermediate steps.
# `--save_sample_prompt` can be same as `--instance_prompt` to generate intermediate samples (saved along with weights in samples directory).
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/accelerate/accelerator.py:231: FutureWarning: `logging_dir` is deprecated and will be removed in version 0.18.0 of 🤗 Accelerate. Use `project_dir` instead.
#   warnings.warn(
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/accelerate/accelerator.py:336: UserWarning: `log_with=tensorboard` was passed but no supported trackers are currently installed.
#   warnings.warn(f"`log_with={log_with}` was passed but no supported trackers are currently installed.")
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/huggingface_hub/utils/_hf_folder.py:92: UserWarning: A token has been found in `/root/.huggingface/token`. This is the old path where tokens were stored. The new location is `/root/.cache/huggingface/token` which is configurable using `HF_HOME` environment variable. Your token has been copied to this new location. You can now safely delete the old token file manually or use `huggingface-cli logout`.
#   warnings.warn(
# Downloading (…)_model.safetensors";: 100%|███| 335M/335M [00:07<00:00, 43.3MB/s]
# Downloading (…)lve/main/config.json: 100%|█████| 547/547 [00:00<00:00, 95.7kB/s]
# Downloading (…)p16/model_index.json: 100%|█████| 543/543 [00:00<00:00, 88.9kB/s]
# Fetching 15 files:   0%|                                 | 0/15 [00:00<?, ?it/s]
# Downloading (…)"pytorch_model.bin";:   0%|           | 0.00/608M [00:00<?, ?B/s]
#
# Downloading (…)"pytorch_model.bin";:   0%|           | 0.00/246M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   2%|  | 10.5M/608M [00:00<00:18, 33.0MB/s]
#
#
# Downloading (…)rocessor_config.json: 100%|██████| 342/342 [00:00<00:00, 171kB/s]
#
#
#
# Downloading (…)_checker/config.json: 100%|█| 4.70k/4.70k [00:00<00:00, 1.34MB/s]
# Fetching 15 files:   7%|█▋                       | 1/15 [00:00<00:10,  1.31it/s]
#
#
# Downloading (…)cheduler_config.json:   0%|            | 0.00/307 [00:00<?, ?B/s]
#
#
#
# Downloading (…)cheduler_config.json: 100%|█████| 307/307 [00:00<00:00, 43.4kB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████| 472/472 [00:00<00:00, 131kB/s]
#
#
#
# Downloading (…)_encoder/config.json: 100%|██████| 636/636 [00:00<00:00, 207kB/s]
#
# Downloading (…)"pytorch_model.bin";:   3%|  | 21.0M/608M [00:00<00:18, 32.3MB/s]
#
#
# Downloading (…)tokenizer/merges.txt:   0%|           | 0.00/525k [00:00<?, ?B/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   5%|  | 31.5M/608M [00:00<00:16, 34.4MB/s]
#
#
#
#
# Downloading (…)okenizer_config.json: 100%|██████| 822/822 [00:00<00:00, 293kB/s]
#
# Downloading (…)"pytorch_model.bin";:   7%|▏ | 41.9M/608M [00:01<00:16, 34.8MB/s]
#
#
#
#
# Downloading (…)cc2/unet/config.json: 100%|██████| 806/806 [00:00<00:00, 444kB/s]
#
#
#
#
#
# Downloading (…)tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading (…)"pytorch_model.bin";:   9%|▏ | 52.4M/608M [00:01<00:16, 33.6MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:   0%|           | 0.00/167M [00:00<?, ?B/s]
#
# Downloading (…)"pytorch_model.bin";:   4%|  | 10.5M/246M [00:01<00:40, 5.88MB/s]
# Downloading (…)"pytorch_model.bin";:  10%|▏ | 62.9M/608M [00:02<00:19, 28.4MB/s]
#
#
#
#
# Downloading (…)tokenizer/vocab.json: 100%|█| 1.06M/1.06M [00:00<00:00, 1.30MB/s]
#
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:   6%|▏ | 10.5M/167M [00:00<00:07, 20.2MB/s]
#
#
#
#
# Downloading (…)9cc2/vae/config.json: 100%|██████| 609/609 [00:00<00:00, 129kB/s]
#
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  13%|▎ | 21.0M/167M [00:00<00:05, 26.5MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  19%|▍ | 31.5M/167M [00:01<00:04, 30.2MB/s]
# Downloading (…)"pytorch_model.bin";:  12%|▏ | 73.4M/608M [00:02<00:28, 18.9MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  25%|▌ | 41.9M/167M [00:01<00:03, 33.2MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  31%|▋ | 52.4M/167M [00:01<00:03, 37.3MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  38%|▊ | 62.9M/167M [00:01<00:02, 40.3MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  44%|▉ | 73.4M/167M [00:02<00:02, 44.2MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  50%|█ | 83.9M/167M [00:02<00:01, 45.5MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  56%|█▏| 94.4M/167M [00:02<00:01, 43.8MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  63%|█▉ | 105M/167M [00:02<00:01, 41.1MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  69%|██ | 115M/167M [00:03<00:01, 41.1MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   1%| | 10.5M/1.72G [00:04<11:04, 2.57MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  75%|██▎| 126M/167M [00:03<00:01, 40.1MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  81%|██▍| 136M/167M [00:03<00:00, 40.7MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  88%|██▋| 147M/167M [00:03<00:00, 40.4MB/s]
#
#
# Downloading (…)tokenizer/merges.txt: 100%|████| 525k/525k [00:04<00:00, 109kB/s]
#
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  94%|██▊| 157M/167M [00:04<00:00, 39.9MB/s]
#
#
#
#
#
# Downloading (…)_pytorch_model.bin";: 100%|███| 167M/167M [00:04<00:00, 38.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  14%|▎ | 83.9M/608M [00:06<01:10, 7.38MB/s]
#
# Downloading (…)"pytorch_model.bin";:   9%|▏ | 21.0M/246M [00:06<01:12, 3.11MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   1%| | 21.0M/1.72G [00:05<07:20, 3.85MB/s]
# Downloading (…)"pytorch_model.bin";:  16%|▎ | 94.4M/608M [00:06<00:57, 8.87MB/s]
#
# Downloading (…)"pytorch_model.bin";:  13%|▎ | 31.5M/246M [00:07<00:45, 4.77MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   2%| | 31.5M/1.72G [00:06<04:51, 5.79MB/s]
# Downloading (…)"pytorch_model.bin";:  17%|▌  | 105M/608M [00:07<00:53, 9.43MB/s]
#
# Downloading (…)"pytorch_model.bin";:  17%|▎ | 41.9M/246M [00:08<00:33, 6.10MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   2%| | 41.9M/1.72G [00:07<03:37, 7.71MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   3%| | 52.4M/1.72G [00:07<02:50, 9.76MB/s]
#
# Downloading (…)"pytorch_model.bin";:  21%|▍ | 52.4M/246M [00:08<00:26, 7.37MB/s]
# Downloading (…)"pytorch_model.bin";:  19%|▌  | 115M/608M [00:09<00:53, 9.28MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   4%| | 62.9M/1.72G [00:08<02:18, 11.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   4%| | 73.4M/1.72G [00:08<01:55, 14.3MB/s]
#
# Downloading (…)"pytorch_model.bin";:  26%|▌ | 62.9M/246M [00:10<00:22, 8.04MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   5%| | 83.9M/1.72G [00:09<01:38, 16.6MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   5%| | 94.4M/1.72G [00:09<01:25, 18.9MB/s]
# Downloading (…)"pytorch_model.bin";:  21%|▌  | 126M/608M [00:10<01:00, 7.92MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   6%|  | 105M/1.72G [00:09<01:18, 20.6MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   7%|▏ | 115M/1.72G [00:10<01:12, 22.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  30%|▌ | 73.4M/246M [00:11<00:21, 8.22MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   7%|▏ | 126M/1.72G [00:10<01:05, 24.2MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   8%|▏ | 136M/1.72G [00:10<00:59, 26.6MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:   9%|▏ | 147M/1.72G [00:11<00:55, 28.5MB/s]
#
# Downloading (…)"pytorch_model.bin";:  34%|▋ | 83.9M/246M [00:12<00:19, 8.46MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";
B/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  49%|▉ | 849M/1.72G [00:33<00:24, 35.4MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  50%|█ | 860M/1.72G [00:34<00:23, 36.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  51%|█ | 870M/1.72G [00:34<00:25, 33.6MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  51%|█ | 881M/1.72G [00:34<00:24, 34.1MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  52%|█ | 891M/1.72G [00:35<00:24, 34.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  52%|█ | 902M/1.72G [00:35<00:24, 32.8MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  53%|█ | 912M/1.72G [00:35<00:29, 27.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  54%|█ | 923M/1.72G [00:36<00:26, 29.6MB/s]
#
# Downloading (…)"pytorch_model.bin";:  89%|██▋| 220M/246M [00:37<00:06, 4.03MB/s]
# Downloading (…)"pytorch_model.bin";:  38%|█▏ | 231M/608M [00:37<01:40, 3.77MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  54%|█ | 933M/1.72G [00:36<00:25, 31.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  55%|█ | 944M/1.72G [00:36<00:22, 34.4MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  55%|█ | 954M/1.72G [00:37<00:21, 35.5MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  56%|█ | 965M/1.72G [00:37<00:21, 35.0MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  57%|█▏| 975M/1.72G [00:37<00:21, 34.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  57%|█▏| 986M/1.72G [00:37<00:20, 35.5MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  58%|█▏| 996M/1.72G [00:38<00:20, 35.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  59%|▌| 1.01G/1.72G [00:38<00:20, 35.5MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  59%|▌| 1.02G/1.72G [00:38<00:21, 32.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  60%|▌| 1.03G/1.72G [00:39<00:21, 31.9MB/s]
#
# Downloading (…)"pytorch_model.bin";:  94%|██▊| 231M/246M [00:40<00:04, 3.84MB/s]
# Downloading (…)"pytorch_model.bin";:  40%|█▏ | 241M/608M [00:40<01:40, 3.66MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  60%|▌| 1.04G/1.72G [00:39<00:21, 31.2MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  61%|▌| 1.05G/1.72G [00:39<00:21, 30.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  62%|▌| 1.06G/1.72G [00:40<00:21, 30.8MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  62%|▌| 1.07G/1.72G [00:40<00:20, 31.2MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  63%|▋| 1.08G/1.72G [00:41<00:20, 31.0MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  63%|▋| 1.09G/1.72G [00:41<00:19, 32.1MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  64%|▋| 1.10G/1.72G [00:41<00:20, 30.7MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  65%|▋| 1.11G/1.72G [00:42<00:19, 31.0MB/s]
# Downloading (…)"pytorch_model.bin";:  41%|█▏ | 252M/608M [00:42<01:32, 3.84MB/s]
#
# Downloading (…)"pytorch_model.bin";:  98%|██▉| 241M/246M [00:43<00:01, 3.86MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  65%|▋| 1.12G/1.72G [00:42<00:18, 32.0MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  66%|▋| 1.13G/1.72G [00:42<00:18, 32.1MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  66%|▋| 1.14G/1.72G [00:42<00:17, 32.8MB/s]
#
# Downloading (…)"pytorch_model.bin";: 100%|███| 246M/246M [00:44<00:00, 5.57MB/s]
#
#
#
#
# Downloading (…)_pytorch_model.bin";:  67%|▋| 1.15G/1.72G [00:43<00:17, 31.6MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  68%|▋| 1.16G/1.72G [00:43<00:16, 32.8MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  68%|▋| 1.17G/1.72G [00:43<00:16, 33.9MB/s]
# Downloading (…)"pytorch_model.bin";:  43%|█▎ | 262M/608M [00:44<01:23, 4.16MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  69%|▋| 1.18G/1.72G [00:44<00:14, 36.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  70%|▋| 1.20G/1.72G [00:44<00:14, 35.6MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  70%|▋| 1.21G/1.72G [00:44<00:13, 36.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  71%|▋| 1.22G/1.72G [00:44<00:13, 36.0MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:
B/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  91%|▉| 1.56G/1.72G [00:55<00:05, 26.3MB/s]
# Downloading (…)"pytorch_model.bin";:  64%|█▉ | 388M/608M [00:57<00:18, 12.2MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  91%|▉| 1.57G/1.72G [00:56<00:06, 21.0MB/s]
# Downloading (…)"pytorch_model.bin";:  66%|█▉ | 398M/608M [00:57<00:14, 14.1MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  92%|▉| 1.58G/1.72G [00:57<00:06, 21.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  93%|▉| 1.59G/1.72G [00:57<00:05, 22.9MB/s]
# Downloading (…)"pytorch_model.bin";:  67%|██ | 409M/608M [00:58<00:12, 15.4MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  93%|▉| 1.60G/1.72G [00:57<00:04, 23.9MB/s]
# Downloading (…)"pytorch_model.bin";:  69%|██ | 419M/608M [00:59<00:12, 15.5MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  94%|▉| 1.61G/1.72G [00:58<00:04, 25.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  95%|▉| 1.63G/1.72G [00:58<00:03, 28.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  95%|▉| 1.64G/1.72G [00:58<00:02, 29.2MB/s]
# Downloading (…)"pytorch_model.bin";:  71%|██ | 430M/608M [00:59<00:12, 14.8MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  96%|▉| 1.65G/1.72G [00:59<00:02, 31.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  96%|▉| 1.66G/1.72G [00:59<00:01, 32.3MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  97%|▉| 1.67G/1.72G [00:59<00:01, 34.4MB/s]
# Downloading (…)"pytorch_model.bin";:  72%|██▏| 440M/608M [01:00<00:11, 14.5MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  98%|▉| 1.68G/1.72G [00:59<00:01, 35.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  98%|▉| 1.69G/1.72G [01:00<00:00, 35.9MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  99%|▉| 1.70G/1.72G [01:00<00:00, 33.6MB/s]
# Downloading (…)"pytorch_model.bin";:  74%|██▏| 451M/608M [01:01<00:11, 13.2MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";:  99%|▉| 1.71G/1.72G [01:00<00:00, 33.2MB/s]
#
#
#
# Downloading (…)_pytorch_model.bin";: 100%|█| 1.72G/1.72G [01:01<00:00, 28.1MB/s]
#
# Downloading (…)"pytorch_model.bin";:  76%|██▎| 461M/608M [01:02<00:10, 14.0MB/s]
# Downloading (…)"pytorch_model.bin";:  78%|██▎| 472M/608M [01:02<00:07, 17.6MB/s]
# Downloading (…)"pytorch_model.bin";:  79%|██▍| 482M/608M [01:02<00:05, 21.5MB/s]
# Downloading (…)"pytorch_model.bin";:  81%|██▍| 493M/608M [01:02<00:04, 25.1MB/s]
# Downloading (…)"pytorch_model.bin";:  83%|██▍| 503M/608M [01:03<00:03, 28.0MB/s]
# Downloading (…)"pytorch_model.bin";:  84%|██▌| 514M/608M [01:03<00:02, 31.9MB/s]
# Downloading (…)"pytorch_model.bin";:  86%|██▌| 524M/608M [01:03<00:02, 34.4MB/s]
# Downloading (…)"pytorch_model.bin";:  88%|██▋| 535M/608M [01:03<00:01, 37.8MB/s]
# Downloading (…)"pytorch_model.bin";:  90%|██▋| 545M/608M [01:04<00:01, 39.4MB/s]
# Downloading (…)"pytorch_model.bin";:  91%|██▋| 556M/608M [01:04<00:01, 38.9MB/s]
# Downloading (…)"pytorch_model.bin";:  93%|██▊| 566M/608M [01:04<00:01, 40.7MB/s]
# Downloading (…)"pytorch_model.bin";:  95%|██▊| 577M/608M [01:04<00:00, 40.7MB/s]
# Downloading (…)"pytorch_model.bin";:  97%|██▉| 587M/608M [01:05<00:00, 41.5MB/s]
# Downloading (…)"pytorch_model.bin";:  98%|██▉| 598M/608M [01:05<00:00, 39.6MB/s]
# Downloading (…)"pytorch_model.bin";: 100%|███| 608M/608M [01:05<00:00, 9.25MB/s]
# Fetching 15 files: 100%|████████████████████████| 15/15 [01:06<00:00,  4.41s/it]
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 02/22/2023 21:31:30 - INFO - __main__ - Number of class images to sample: 50.
# Generating class images: 100%|██████████████████| 13/13 [01:00<00:00,  4.68s/it]
# Downloading (…)tokenizer/vocab.json: 100%|██| 1.06M/1.06M [00:02<00:00, 379kB/s]
# Downloading (…)tokenizer/merges.txt: 100%|███| 525k/525k [00:00<00:00, 1.19MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████| 472/472 [00:00<00:00, 130kB/s]
# Downloading (…)okenizer_config.json: 100%|██████| 822/822 [00:00<00:00, 225kB/s]
# Downloading (…)_encoder/config.json: 100%|██████| 636/636 [00:00<00:00, 132kB/s]
# Downloading (…)"pytorch_model.bin";: 100%|███| 246M/246M [00:05<00:00, 42.9MB/s]
#
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link
# ================================================================================
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/local/nvidia/lib64'), PosixPath('/usr/local/nvidia/lib')}
#   warn(
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/bitsandbytes/cuda_setup/paths.py:105: UserWarning: /usr/local/nvidia/lib:/usr/local/nvidia/lib64 did not contain libcudart.so as expected! Searching further paths...
#   warn(
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('//matplotlib_inline.backend_inline'), PosixPath('module')}
#   warn(
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('nvidia/cuda'), PosixPath('11.6.0-cudnn8-runtime-ubuntu20.04')}
#   warn(
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/bitsandbytes/cuda_setup/paths.py:27: UserWarning: WARNING: The following directories listed in your path were found to be non-existent: {PosixPath('/usr/lib/python38.zip')}
#   warn(
# CUDA_SETUP: WARNING! libcudart.so not found in any environmental path. Searching /usr/local/cuda/lib64...
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda/lib64/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 8.6
# CUDA SETUP: Detected CUDA version 116
# CUDA SETUP: Loading binary /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/bitsandbytes/libbitsandbytes_cuda116.so...
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/diffusers/configuration_utils.py:195: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a scheduler, please use <class 'diffusers.schedulers.scheduling_ddpm.DDPMScheduler'>.from_pretrained(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Downloading (…)cheduler_config.json: 100%|██████| 308/308 [00:00<00:00, 154kB/s]
# Caching latents: 100%|██████████████████████████| 50/50 [00:03<00:00, 14.03it/s]
# 02/22/2023 21:32:55 - INFO - __main__ - ***** Running training *****
# 02/22/2023 21:32:55 - INFO - __main__ -   Num examples = 50
# 02/22/2023 21:32:55 - INFO - __main__ -   Num batches each epoch = 50
# 02/22/2023 21:32:55 - INFO - __main__ -   Num Epochs = 16
# 02/22/2023 21:32:55 - INFO - __main__ -   Instantaneous batch size per device = 1
# 02/22/2023 21:32:55 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 1
# 02/22/2023 21:32:55 - INFO - __main__ -   Gradient Accumulation steps = 1
# 02/22/2023 21:32:55 - INFO - __main__ -   Total optimization steps = 800
# Steps: 100%|█████████████| 800/800 [03:41<00:00,  3.76it/s, loss=0.258, lr=1e-6]
# Fetching 15 files: 100%|█████████████████████| 15/15 [00:00<00:00, 73326.99it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#
# Generating samples:   0%|                                 | 0/4 [00:00<?, ?it/s]
# Generating samples:  25%|██████▎                  | 1/4 [00:02<00:08,  2.82s/it]
# Generating samples:  50%|████████████▌            | 2/4 [00:04<00:03,  1.90s/it]
# Generating samples:  75%|██████████████████▊      | 3/4 [00:05<00:01,  1.60s/it]
# Generating samples: 100%|█████████████████████████| 4/4 [00:06<00:00,  1.64s/it]
# [*] Weights saved at content/stable_diffusion_weights/bfn/800
# Steps: 100%|█████████████| 800/800 [03:54<00:00,  3.41it/s, loss=0.258, lr=1e-6]

# %%
#@markdown Specify the weights directory to use (leave blank for latest)
WEIGHTS_DIR = "" #@param {type:"string"}
if WEIGHTS_DIR == "":
    from natsort import natsorted
    from glob import glob
    import os
    WEIGHTS_DIR = natsorted(glob(OUTPUT_DIR + os.sep + "*"))[-1]
print(f"[*] WEIGHTS_DIR={WEIGHTS_DIR}")
# Out:
# [*] WEIGHTS_DIR=content/stable_diffusion_weights/bfn/800

# %%
#@markdown Run to generate a grid of preview images from the last saved weights.
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

weights_folder = OUTPUT_DIR
folders = sorted([f for f in os.listdir(weights_folder) if f != "0"], key=lambda x: int(x))

row = len(folders)
print(folders[0])
col = len(os.listdir(os.path.join(weights_folder, folders[0], "samples")))
scale = 4
fig, axes = plt.subplots(row, col, figsize=(col*scale, row*scale), gridspec_kw={'hspace': 0, 'wspace': 0})

for i, folder in enumerate(folders):
    folder_path = os.path.join(weights_folder, folder)
    image_folder = os.path.join(folder_path, "samples")
    images = [f for f in os.listdir(image_folder)]
    for j, image in enumerate(images):
        if row == 1:
            currAxes = axes[j]
        else:
            currAxes = axes[i, j]
        if i == 0:
            currAxes.set_title(f"Image {j}")
        if j == 0:
            currAxes.text(-0.1, 0.5, folder, rotation=0, va='center', ha='center', transform=currAxes.transAxes)
        image_path = os.path.join(image_folder, image)
        img = mpimg.imread(image_path)
        currAxes.imshow(img, cmap='gray')
        currAxes.axis('off')
        
plt.tight_layout()
plt.savefig('grid.png', dpi=72)
# Out:
# 800

# %% [markdown]
# ## Convert weights to ckpt to use in web UIs like AUTOMATIC1111.

# %%
#@markdown Run conversion.
ckpt_path = WEIGHTS_DIR + "/model.ckpt"

half_arg = ""
#@markdown  Whether to convert to fp16, takes half the space (2GB).
fp16 = True #@param {type: "boolean"}
if fp16:
    half_arg = "--half"
# !python convert_diffusers_to_original_stable_diffusion.py --model_path $WEIGHTS_DIR  --checkpoint_path $ckpt_path $half_arg
print(f"[*] Converted ckpt saved at {ckpt_path}")
# Out:
# Reshaping encoder.mid.attn_1.q.weight for SD format
# Reshaping encoder.mid.attn_1.k.weight for SD format
# Reshaping encoder.mid.attn_1.v.weight for SD format
# Reshaping encoder.mid.attn_1.proj_out.weight for SD format
# Reshaping decoder.mid.attn_1.q.weight for SD format
# Reshaping decoder.mid.attn_1.k.weight for SD format
# Reshaping decoder.mid.attn_1.v.weight for SD format
# Reshaping decoder.mid.attn_1.proj_out.weight for SD format
# [*] Converted ckpt saved at content/stable_diffusion_weights/bfn/800/model.ckpt

# %% [markdown]
# ## Inference

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline, DDIMScheduler
from IPython.display import display

model_path = WEIGHTS_DIR # If you want to use previously trained model saved in gdrive, replace this with the full path of model in gdrive

pipe = StableDiffusionPipeline.from_pretrained(model_path, safety_checker=None, torch_dtype=torch.float16).to("cuda")
pipe.scheduler = DDIMScheduler.from_config(pipe.scheduler.config)
pipe.enable_xformers_memory_efficient_attention()
g_cuda = None
# Out:
# /root/.clearml/venvs-builds/3.8/lib/python3.8/site-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .

# %%
#@markdown Can set random seed here for reproducibility.
g_cuda = torch.Generator(device='cuda')
seed = 645678 #@param {type:"number"}
g_cuda.manual_seed(seed)

# %%
#@title Run for generating images.

prompt = f"photo of {OBJECT_NAME} bear cooking" #@param {type:"string"}
negative_prompt = "" #@param {type:"string"}
num_samples = 4 #@param {type:"number"}
guidance_scale = 7.5 #@param {type:"number"}
num_inference_steps = 24 #@param {type:"number"}
height = 512 #@param {type:"number"}
width = 512 #@param {type:"number"}

with autocast("cuda"), torch.inference_mode():
    images = pipe(
        prompt,
        height=height,
        width=width,
        negative_prompt=negative_prompt,
        num_images_per_prompt=num_samples,
        num_inference_steps=num_inference_steps,
        guidance_scale=guidance_scale,
        generator=g_cuda
    ).images

for img in images:
    display(img)
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>
# <PIL.Image.Image image mode=RGB size=512x512>

# %% [markdown]
# ## Free up drive space (Caution!)

# %%
#@title (Optional) Delete diffuser and old weights and only keep the ckpt to free up drive space.

#@markdown [ ! ] Caution, Only execute if you are sure u want to delete the diffuser format weights and only use the ckpt.
import shutil
from glob import glob
import os
for f in glob(OUTPUT_DIR+os.sep+"*"):
    if f != WEIGHTS_DIR:
        shutil.rmtree(f)
        print("Deleted", f)
for f in glob(WEIGHTS_DIR+"/*"):
    if not f.endswith(".ckpt") or not f.endswith(".json"):
        try:
            shutil.rmtree(f)
        except NotADirectoryError:
            continue
        print("Deleted", f)
# Out:
# Deleted /content/stable_diffusion_weights/zwx/800/vae
# Deleted /content/stable_diffusion_weights/zwx/800/samples
# Deleted /content/stable_diffusion_weights/zwx/800/scheduler
# Deleted /content/stable_diffusion_weights/zwx/800/tokenizer
# Deleted /content/stable_diffusion_weights/zwx/800/unet
# Deleted /content/stable_diffusion_weights/zwx/800/feature_extractor
# Deleted /content/stable_diffusion_weights/zwx/800/text_encoder

# %%
#@title Free runtime memory
exit()
